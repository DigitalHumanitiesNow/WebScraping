# %% [markdown]
# # Topic Modeling Editors' Choice articles from *Digital Humanities Now*

# %% [markdown]
# This notebook steps through the process of analyzing articles from DHNow using a couple of techniques.

# %% [markdown]
# ###Assemble a corpus of articles
# First we'll get our articles from the file system. We'll use the `glob` module to grab just the numbered .txt files.

# %%
import os
import glob
filenames = glob.glob('inputs/[0-9]*.txt')

# %% [markdown]
# We can quickly check to make sure we've got the right files by inspecting the `filenames` list we've just created.

# %%
filenames
# Out:
# ['inputs/1.txt',
#  'inputs/10.txt',
#  'inputs/100.txt',
#  'inputs/1000.txt',
#  'inputs/1001.txt',
#  'inputs/1002.txt',
#  'inputs/1003.txt',
#  'inputs/1004.txt',
#  'inputs/1005.txt',
#  'inputs/1006.txt',
#  'inputs/1007.txt',
#  'inputs/1008.txt',
#  'inputs/1009.txt',
#  'inputs/101.txt',
#  'inputs/1010.txt',
#  'inputs/1011.txt',
#  'inputs/1012.txt',
#  'inputs/1013.txt',
#  'inputs/1014.txt',
#  'inputs/1015.txt',
#  'inputs/1016.txt',
#  'inputs/1017.txt',
#  'inputs/1018.txt',
#  'inputs/1019.txt',
#  'inputs/102.txt',
#  'inputs/1020.txt',
#  'inputs/1021.txt',
#  'inputs/1022.txt',
#  'inputs/1023.txt',
#  'inputs/1024.txt',
#  'inputs/1025.txt',
#  'inputs/1026.txt',
#  'inputs/1027.txt',
#  'inputs/1028.txt',
#  'inputs/1029.txt',
#  'inputs/103.txt',
#  'inputs/1030.txt',
#  'inputs/1031.txt',
#  'inputs/1032.txt',
#  'inputs/1033.txt',
#  'inputs/1034.txt',
#  'inputs/1035.txt',
#  'inputs/1036.txt',
#  'inputs/1037.txt',
#  'inputs/1038.txt',
#  'inputs/1039.txt',
#  'inputs/104.txt',
#  'inputs/1040.txt',
#  'inputs/1041.txt',
#  'inputs/1042.txt',
#  'inputs/1043.txt',
#  'inputs/1044.txt',
#  'inputs/1045.txt',
#  'inputs/1046.txt',
#  'inputs/1047.txt',
#  'inputs/1048.txt',
#  'inputs/1049.txt',
#  'inputs/105.txt',
#  'inputs/1050.txt',
#  'inputs/1051.txt',
#  'inputs/1052.txt',
#  'inputs/1053.txt',
#  'inputs/1054.txt',
#  'inputs/1055.txt',
#  'inputs/1056.txt',
#  'inputs/1057.txt',
#  'inputs/1058.txt',
#  'inputs/1059.txt',
#  'inputs/106.txt',
#  'inputs/1060.txt',
#  'inputs/1061.txt',
#  'inputs/1062.txt',
#  'inputs/1063.txt',
#  'inputs/1064.txt',
#  'inputs/1065.txt',
#  'inputs/1066.txt',
#  'inputs/1067.txt',
#  'inputs/1068.txt',
#  'inputs/1069.txt',
#  'inputs/107.txt',
#  'inputs/1070.txt',
#  'inputs/1071.txt',
#  'inputs/1072.txt',
#  'inputs/1073.txt',
#  'inputs/1074.txt',
#  'inputs/1075.txt',
#  'inputs/1076.txt',
#  'inputs/1077.txt',
#  'inputs/1078.txt',
#  'inputs/1079.txt',
#  'inputs/108.txt',
#  'inputs/1080.txt',
#  'inputs/1081.txt',
#  'inputs/1082.txt',
#  'inputs/1083.txt',
#  'inputs/1084.txt',
#  'inputs/1085.txt',
#  'inputs/1086.txt',
#  'inputs/1087.txt',
#  'inputs/1088.txt',
#  'inputs/1089.txt',
#  'inputs/109.txt',
#  'inputs/1090.txt',
#  'inputs/1091.txt',
#  'inputs/1092.txt',
#  'inputs/1093.txt',
#  'inputs/1094.txt',
#  'inputs/1095.txt',
#  'inputs/1096.txt',
#  'inputs/1097.txt',
#  'inputs/1098.txt',
#  'inputs/1099.txt',
#  'inputs/11.txt',
#  'inputs/110.txt',
#  'inputs/1100.txt',
#  'inputs/1101.txt',
#  'inputs/1102.txt',
#  'inputs/1103.txt',
#  'inputs/1104.txt',
#  'inputs/1105.txt',
#  'inputs/1106.txt',
#  'inputs/1107.txt',
#  'inputs/1108.txt',
#  'inputs/1109.txt',
#  'inputs/111.txt',
#  'inputs/1110.txt',
#  'inputs/1111.txt',
#  'inputs/1112.txt',
#  'inputs/1113.txt',
#  'inputs/1114.txt',
#  'inputs/1115.txt',
#  'inputs/1116.txt',
#  'inputs/1117.txt',
#  'inputs/1118.txt',
#  'inputs/1119.txt',
#  'inputs/112.txt',
#  'inputs/1120.txt',
#  'inputs/1121.txt',
#  'inputs/1122.txt',
#  'inputs/1123.txt',
#  'inputs/1124.txt',
#  'inputs/1125.txt',
#  'inputs/1126.txt',
#  'inputs/1127.txt',
#  'inputs/1128.txt',
#  'inputs/1129.txt',
#  'inputs/113.txt',
#  'inputs/1130.txt',
#  'inputs/1131.txt',
#  'inputs/1132.txt',
#  'inputs/1133.txt',
#  'inputs/1134.txt',
#  'inputs/1135.txt',
#  'inputs/1136.txt',
#  'inputs/1137.txt',
#  'inputs/1138.txt',
#  'inputs/1139.txt',
#  'inputs/114.txt',
#  'inputs/1140.txt',
#  'inputs/1141.txt',
#  'inputs/1142.txt',
#  'inputs/1143.txt',
#  'inputs/1144.txt',
#  'inputs/1145.txt',
#  'inputs/1146.txt',
#  'inputs/1147.txt',
#  'inputs/1148.txt',
#  'inputs/1149.txt',
#  'inputs/115.txt',
#  'inputs/1150.txt',
#  'inputs/1151.txt',
#  'inputs/1152.txt',
#  'inputs/1153.txt',
#  'inputs/1154.txt',
#  'inputs/1155.txt',
#  'inputs/1156.txt',
#  'inputs/1157.txt',
#  'inputs/1158.txt',
#  'inputs/1159.txt',
#  'inputs/116.txt',
#  'inputs/1160.txt',
#  'inputs/1161.txt',
#  'inputs/1162.txt',
#  'inputs/1163.txt',
#  'inputs/1164.txt',
#  'inputs/1165.txt',
#  'inputs/1166.txt',
#  'inputs/1167.txt',
#  'inputs/1168.txt',
#  'inputs/1169.txt',
#  'inputs/117.txt',
#  'inputs/1170.txt',
#  'inputs/1171.txt',
#  'inputs/1172.txt',
#  'inputs/1173.txt',
#  'inputs/1174.txt',
#  'inputs/1175.txt',
#  'inputs/1176.txt',
#  'inputs/1177.txt',
#  'inputs/1178.txt',
#  'inputs/1179.txt',
#  'inputs/118.txt',
#  'inputs/1180.txt',
#  'inputs/1181.txt',
#  'inputs/1182.txt',
#  'inputs/1183.txt',
#  'inputs/1184.txt',
#  'inputs/1185.txt',
#  'inputs/1186.txt',
#  'inputs/1187.txt',
#  'inputs/1188.txt',
#  'inputs/1189.txt',
#  'inputs/119.txt',
#  'inputs/1190.txt',
#  'inputs/1191.txt',
#  'inputs/1192.txt',
#  'inputs/1193.txt',
#  'inputs/1194.txt',
#  'inputs/1195.txt',
#  'inputs/1196.txt',
#  'inputs/1197.txt',
#  'inputs/1198.txt',
#  'inputs/1199.txt',
#  'inputs/12.txt',
#  'inputs/120.txt',
#  'inputs/1200.txt',
#  'inputs/1201.txt',
#  'inputs/1202.txt',
#  'inputs/1203.txt',
#  'inputs/1204.txt',
#  'inputs/1205.txt',
#  'inputs/1206.txt',
#  'inputs/1207.txt',
#  'inputs/1208.txt',
#  'inputs/1209.txt',
#  'inputs/121.txt',
#  'inputs/1210.txt',
#  'inputs/1211.txt',
#  'inputs/1212.txt',
#  'inputs/1213.txt',
#  'inputs/1214.txt',
#  'inputs/1215.txt',
#  'inputs/1216.txt',
#  'inputs/1217.txt',
#  'inputs/1218.txt',
#  'inputs/1219.txt',
#  'inputs/122.txt',
#  'inputs/1220.txt',
#  'inputs/1221.txt',
#  'inputs/1222.txt',
#  'inputs/1223.txt',
#  'inputs/1224.txt',
#  'inputs/1225.txt',
#  'inputs/1226.txt',
#  'inputs/1227.txt',
#  'inputs/1228.txt',
#  'inputs/1229.txt',
#  'inputs/123.txt',
#  'inputs/1230.txt',
#  'inputs/1231.txt',
#  'inputs/1232.txt',
#  'inputs/1233.txt',
#  'inputs/1234.txt',
#  'inputs/1235.txt',
#  'inputs/1236.txt',
#  'inputs/1237.txt',
#  'inputs/1238.txt',
#  'inputs/1239.txt',
#  'inputs/124.txt',
#  'inputs/1240.txt',
#  'inputs/1241.txt',
#  'inputs/1242.txt',
#  'inputs/1243.txt',
#  'inputs/1244.txt',
#  'inputs/1245.txt',
#  'inputs/1246.txt',
#  'inputs/1247.txt',
#  'inputs/1248.txt',
#  'inputs/1249.txt',
#  'inputs/125.txt',
#  'inputs/1250.txt',
#  'inputs/1251.txt',
#  'inputs/1252.txt',
#  'inputs/1253.txt',
#  'inputs/1254.txt',
#  'inputs/1255.txt',
#  'inputs/1256.txt',
#  'inputs/1257.txt',
#  'inputs/1258.txt',
#  'inputs/1259.txt',
#  'inputs/126.txt',
#  'inputs/1260.txt',
#  'inputs/1261.txt',
#  'inputs/1262.txt',
#  'inputs/1263.txt',
#  'inputs/1264.txt',
#  'inputs/1265.txt',
#  'inputs/1266.txt',
#  'inputs/1267.txt',
#  'inputs/1268.txt',
#  'inputs/1269.txt',
#  'inputs/127.txt',
#  'inputs/1270.txt',
#  'inputs/1271.txt',
#  'inputs/1272.txt',
#  'inputs/1273.txt',
#  'inputs/1274.txt',
#  'inputs/1275.txt',
#  'inputs/1276.txt',
#  'inputs/1277.txt',
#  'inputs/1278.txt',
#  'inputs/1279.txt',
#  'inputs/128.txt',
#  'inputs/1280.txt',
#  'inputs/1281.txt',
#  'inputs/1282.txt',
#  'inputs/1283.txt',
#  'inputs/1284.txt',
#  'inputs/1285.txt',
#  'inputs/1286.txt',
#  'inputs/1287.txt',
#  'inputs/1288.txt',
#  'inputs/1289.txt',
#  'inputs/129.txt',
#  'inputs/1290.txt',
#  'inputs/1291.txt',
#  'inputs/1292.txt',
#  'inputs/1293.txt',
#  'inputs/1294.txt',
#  'inputs/1295.txt',
#  'inputs/1296.txt',
#  'inputs/1297.txt',
#  'inputs/1298.txt',
#  'inputs/1299.txt',
#  'inputs/13.txt',
#  'inputs/130.txt',
#  'inputs/1300.txt',
#  'inputs/1301.txt',
#  'inputs/1302.txt',
#  'inputs/1303.txt',
#  'inputs/1304.txt',
#  'inputs/1305.txt',
#  'inputs/1306.txt',
#  'inputs/1307.txt',
#  'inputs/1308.txt',
#  'inputs/1309.txt',
#  'inputs/131.txt',
#  'inputs/1310.txt',
#  'inputs/1311.txt',
#  'inputs/1312.txt',
#  'inputs/1313.txt',
#  'inputs/1314.txt',
#  'inputs/1315.txt',
#  'inputs/1316.txt',
#  'inputs/1317.txt',
#  'inputs/1318.txt',
#  'inputs/1319.txt',
#  'inputs/132.txt',
#  'inputs/1320.txt',
#  'inputs/1321.txt',
#  'inputs/1322.txt',
#  'inputs/1323.txt',
#  'inputs/1324.txt',
#  'inputs/1325.txt',
#  'inputs/1326.txt',
#  'inputs/1327.txt',
#  'inputs/1328.txt',
#  'inputs/1329.txt',
#  'inputs/133.txt',
#  'inputs/1330.txt',
#  'inputs/1331.txt',
#  'inputs/1332.txt',
#  'inputs/1333.txt',
#  'inputs/1334.txt',
#  'inputs/1335.txt',
#  'inputs/1336.txt',
#  'inputs/1337.txt',
#  'inputs/1338.txt',
#  'inputs/1339.txt',
#  'inputs/134.txt',
#  'inputs/1340.txt',
#  'inputs/1341.txt',
#  'inputs/1342.txt',
#  'inputs/1343.txt',
#  'inputs/1344.txt',
#  'inputs/1345.txt',
#  'inputs/1346.txt',
#  'inputs/1347.txt',
#  'inputs/1348.txt',
#  'inputs/1349.txt',
#  'inputs/135.txt',
#  'inputs/1350.txt',
#  'inputs/1351.txt',
#  'inputs/1352.txt',
#  'inputs/1353.txt',
#  'inputs/1354.txt',
#  'inputs/1355.txt',
#  'inputs/1356.txt',
#  'inputs/1357.txt',
#  'inputs/1358.txt',
#  'inputs/1359.txt',
#  'inputs/136.txt',
#  'inputs/1360.txt',
#  'inputs/1361.txt',
#  'inputs/1362.txt',
#  'inputs/1363.txt',
#  'inputs/1364.txt',
#  'inputs/1365.txt',
#  'inputs/1366.txt',
#  'inputs/1367.txt',
#  'inputs/1368.txt',
#  'inputs/1369.txt',
#  'inputs/137.txt',
#  'inputs/1370.txt',
#  'inputs/1371.txt',
#  'inputs/1372.txt',
#  'inputs/1373.txt',
#  'inputs/1374.txt',
#  'inputs/1375.txt',
#  'inputs/1376.txt',
#  'inputs/1377.txt',
#  'inputs/1378.txt',
#  'inputs/1379.txt',
#  'inputs/138.txt',
#  'inputs/1380.txt',
#  'inputs/1381.txt',
#  'inputs/1382.txt',
#  'inputs/1383.txt',
#  'inputs/1384.txt',
#  'inputs/1385.txt',
#  'inputs/1386.txt',
#  'inputs/1387.txt',
#  'inputs/1388.txt',
#  'inputs/1389.txt',
#  'inputs/139.txt',
#  'inputs/1390.txt',
#  'inputs/1391.txt',
#  'inputs/1392.txt',
#  'inputs/1393.txt',
#  'inputs/1394.txt',
#  'inputs/1395.txt',
#  'inputs/1396.txt',
#  'inputs/1397.txt',
#  'inputs/1398.txt',
#  'inputs/1399.txt',
#  'inputs/14.txt',
#  'inputs/140.txt',
#  'inputs/1400.txt',
#  'inputs/1401.txt',
#  'inputs/1402.txt',
#  'inputs/1403.txt',
#  'inputs/1404.txt',
#  'inputs/1405.txt',
#  'inputs/1406.txt',
#  'inputs/1407.txt',
#  'inputs/1408.txt',
#  'inputs/1409.txt',
#  'inputs/141.txt',
#  'inputs/1410.txt',
#  'inputs/1411.txt',
#  'inputs/1412.txt',
#  'inputs/1413.txt',
#  'inputs/1414.txt',
#  'inputs/1415.txt',
#  'inputs/1416.txt',
#  'inputs/1417.txt',
#  'inputs/1418.txt',
#  'inputs/1419.txt',
#  'inputs/142.txt',
#  'inputs/1420.txt',
#  'inputs/1421.txt',
#  'inputs/1422.txt',
#  'inputs/1423.txt',
#  'inputs/1424.txt',
#  'inputs/1425.txt',
#  'inputs/1426.txt',
#  'inputs/1427.txt',
#  'inputs/1428.txt',
#  'inputs/1429.txt',
#  'inputs/143.txt',
#  'inputs/1430.txt',
#  'inputs/1431.txt',
#  'inputs/1432.txt',
#  'inputs/1433.txt',
#  'inputs/1434.txt',
#  'inputs/1435.txt',
#  'inputs/1436.txt',
#  'inputs/1437.txt',
#  'inputs/1438.txt',
#  'inputs/1439.txt',
#  'inputs/144.txt',
#  'inputs/1440.txt',
#  'inputs/1441.txt',
#  'inputs/1442.txt',
#  'inputs/1443.txt',
#  'inputs/1444.txt',
#  'inputs/1445.txt',
#  'inputs/1446.txt',
#  'inputs/1447.txt',
#  'inputs/1448.txt',
#  'inputs/1449.txt',
#  'inputs/145.txt',
#  'inputs/1450.txt',
#  'inputs/1451.txt',
#  'inputs/1452.txt',
#  'inputs/1453.txt',
#  'inputs/1454.txt',
#  'inputs/1455.txt',
#  'inputs/1456.txt',
#  'inputs/1457.txt',
#  'inputs/1458.txt',
#  'inputs/1459.txt',
#  'inputs/146.txt',
#  'inputs/1460.txt',
#  'inputs/1461.txt',
#  'inputs/1462.txt',
#  'inputs/1463.txt',
#  'inputs/1464.txt',
#  'inputs/1465.txt',
#  'inputs/1466.txt',
#  'inputs/1467.txt',
#  'inputs/1468.txt',
#  'inputs/1469.txt',
#  'inputs/147.txt',
#  'inputs/1470.txt',
#  'inputs/1471.txt',
#  'inputs/1472.txt',
#  'inputs/1473.txt',
#  'inputs/1474.txt',
#  'inputs/1475.txt',
#  'inputs/1476.txt',
#  'inputs/1477.txt',
#  'inputs/1478.txt',
#  'inputs/1479.txt',
#  'inputs/148.txt',
#  'inputs/1480.txt',
#  'inputs/1481.txt',
#  'inputs/1482.txt',
#  'inputs/1483.txt',
#  'inputs/1484.txt',
#  'inputs/1485.txt',
#  'inputs/1486.txt',
#  'inputs/1487.txt',
#  'inputs/1488.txt',
#  'inputs/1489.txt',
#  'inputs/149.txt',
#  'inputs/1490.txt',
#  'inputs/1491.txt',
#  'inputs/1492.txt',
#  'inputs/1493.txt',
#  'inputs/1494.txt',
#  'inputs/1495.txt',
#  'inputs/1496.txt',
#  'inputs/1497.txt',
#  'inputs/1498.txt',
#  'inputs/1499.txt',
#  'inputs/15.txt',
#  'inputs/150.txt',
#  'inputs/1500.txt',
#  'inputs/1501.txt',
#  'inputs/1502.txt',
#  'inputs/1503.txt',
#  'inputs/1504.txt',
#  'inputs/1505.txt',
#  'inputs/1506.txt',
#  'inputs/1507.txt',
#  'inputs/1508.txt',
#  'inputs/1509.txt',
#  'inputs/151.txt',
#  'inputs/1510.txt',
#  'inputs/1511.txt',
#  'inputs/1512.txt',
#  'inputs/1513.txt',
#  'inputs/1514.txt',
#  'inputs/1515.txt',
#  'inputs/1516.txt',
#  'inputs/1517.txt',
#  'inputs/1518.txt',
#  'inputs/1519.txt',
#  'inputs/152.txt',
#  'inputs/1520.txt',
#  'inputs/1521.txt',
#  'inputs/1522.txt',
#  'inputs/1523.txt',
#  'inputs/1524.txt',
#  'inputs/1525.txt',
#  'inputs/1526.txt',
#  'inputs/1527.txt',
#  'inputs/1528.txt',
#  'inputs/1529.txt',
#  'inputs/153.txt',
#  'inputs/1530.txt',
#  'inputs/1531.txt',
#  'inputs/1532.txt',
#  'inputs/1533.txt',
#  'inputs/1534.txt',
#  'inputs/1535.txt',
#  'inputs/1536.txt',
#  'inputs/1537.txt',
#  'inputs/1538.txt',
#  'inputs/1539.txt',
#  'inputs/154.txt',
#  'inputs/1540.txt',
#  'inputs/1541.txt',
#  'inputs/1542.txt',
#  'inputs/1543.txt',
#  'inputs/1544.txt',
#  'inputs/1545.txt',
#  'inputs/1546.txt',
#  'inputs/1547.txt',
#  'inputs/1548.txt',
#  'inputs/1549.txt',
#  'inputs/155.txt',
#  'inputs/1550.txt',
#  'inputs/1551.txt',
#  'inputs/1552.txt',
#  'inputs/1553.txt',
#  'inputs/1554.txt',
#  'inputs/1555.txt',
#  'inputs/1556.txt',
#  'inputs/1557.txt',
#  'inputs/1558.txt',
#  'inputs/1559.txt',
#  'inputs/156.txt',
#  'inputs/1560.txt',
#  'inputs/1561.txt',
#  'inputs/1562.txt',
#  'inputs/1563.txt',
#  'inputs/1564.txt',
#  'inputs/1565.txt',
#  'inputs/1566.txt',
#  'inputs/1567.txt',
#  'inputs/1568.txt',
#  'inputs/1569.txt',
#  'inputs/157.txt',
#  'inputs/1570.txt',
#  'inputs/1571.txt',
#  'inputs/1572.txt',
#  'inputs/1573.txt',
#  'inputs/1574.txt',
#  'inputs/1575.txt',
#  'inputs/1576.txt',
#  'inputs/1577.txt',
#  'inputs/1578.txt',
#  'inputs/1579.txt',
#  'inputs/158.txt',
#  'inputs/1580.txt',
#  'inputs/1581.txt',
#  'inputs/1582.txt',
#  'inputs/1583.txt',
#  'inputs/1584.txt',
#  'inputs/1585.txt',
#  'inputs/1586.txt',
#  'inputs/1587.txt',
#  'inputs/1588.txt',
#  'inputs/1589.txt',
#  'inputs/159.txt',
#  'inputs/1590.txt',
#  'inputs/1591.txt',
#  'inputs/1592.txt',
#  'inputs/1593.txt',
#  'inputs/1594.txt',
#  'inputs/1595.txt',
#  'inputs/1596.txt',
#  'inputs/1597.txt',
#  'inputs/1598.txt',
#  'inputs/1599.txt',
#  'inputs/16.txt',
#  'inputs/160.txt',
#  'inputs/1600.txt',
#  'inputs/1601.txt',
#  'inputs/1602.txt',
#  'inputs/1603.txt',
#  'inputs/1604.txt',
#  'inputs/1605.txt',
#  'inputs/1606.txt',
#  'inputs/1607.txt',
#  'inputs/1608.txt',
#  'inputs/1609.txt',
#  'inputs/161.txt',
#  'inputs/1610.txt',
#  'inputs/1611.txt',
#  'inputs/1612.txt',
#  'inputs/1613.txt',
#  'inputs/1614.txt',
#  'inputs/1615.txt',
#  'inputs/1616.txt',
#  'inputs/1617.txt',
#  'inputs/1618.txt',
#  'inputs/1619.txt',
#  'inputs/162.txt',
#  'inputs/1620.txt',
#  'inputs/1621.txt',
#  'inputs/1622.txt',
#  'inputs/1623.txt',
#  'inputs/1624.txt',
#  'inputs/1625.txt',
#  'inputs/1626.txt',
#  'inputs/1627.txt',
#  'inputs/1628.txt',
#  'inputs/1629.txt',
#  'inputs/163.txt',
#  'inputs/1630.txt',
#  'inputs/1631.txt',
#  'inputs/1632.txt',
#  'inputs/1633.txt',
#  'inputs/1634.txt',
#  'inputs/1635.txt',
#  'inputs/1636.txt',
#  'inputs/1637.txt',
#  'inputs/1638.txt',
#  'inputs/1639.txt',
#  'inputs/164.txt',
#  'inputs/1640.txt',
#  'inputs/1641.txt',
#  'inputs/1642.txt',
#  'inputs/1643.txt',
#  'inputs/1644.txt',
#  'inputs/1645.txt',
#  'inputs/1646.txt',
#  'inputs/1647.txt',
#  'inputs/1648.txt',
#  'inputs/1649.txt',
#  'inputs/165.txt',
#  'inputs/1650.txt',
#  'inputs/1651.txt',
#  'inputs/1652.txt',
#  'inputs/1653.txt',
#  'inputs/1654.txt',
#  'inputs/1655.txt',
#  'inputs/1656.txt',
#  'inputs/1657.txt',
#  'inputs/1658.txt',
#  'inputs/1659.txt',
#  'inputs/166.txt',
#  'inputs/1660.txt',
#  'inputs/1661.txt',
#  'inputs/1662.txt',
#  'inputs/1663.txt',
#  'inputs/1664.txt',
#  'inputs/1665.txt',
#  'inputs/1666.txt',
#  'inputs/1667.txt',
#  'inputs/1668.txt',
#  'inputs/1669.txt',
#  'inputs/167.txt',
#  'inputs/1670.txt',
#  'inputs/1671.txt',
#  'inputs/1672.txt',
#  'inputs/1673.txt',
#  'inputs/1674.txt',
#  'inputs/1675.txt',
#  'inputs/1676.txt',
#  'inputs/1677.txt',
#  'inputs/1678.txt',
#  'inputs/1679.txt',
#  'inputs/168.txt',
#  'inputs/1680.txt',
#  'inputs/1681.txt',
#  'inputs/1682.txt',
#  'inputs/1683.txt',
#  'inputs/1684.txt',
#  'inputs/1685.txt',
#  'inputs/1686.txt',
#  'inputs/1687.txt',
#  'inputs/1688.txt',
#  'inputs/1689.txt',
#  'inputs/169.txt',
#  'inputs/1690.txt',
#  'inputs/1691.txt',
#  'inputs/1692.txt',
#  'inputs/1693.txt',
#  'inputs/1694.txt',
#  'inputs/1695.txt',
#  'inputs/1696.txt',
#  'inputs/1697.txt',
#  'inputs/1698.txt',
#  'inputs/1699.txt',
#  'inputs/17.txt',
#  'inputs/170.txt',
#  'inputs/1700.txt',
#  'inputs/1701.txt',
#  'inputs/1702.txt',
#  'inputs/1703.txt',
#  'inputs/1704.txt',
#  'inputs/1705.txt',
#  'inputs/1706.txt',
#  'inputs/1707.txt',
#  'inputs/1708.txt',
#  'inputs/1709.txt',
#  'inputs/171.txt',
#  'inputs/1710.txt',
#  'inputs/1711.txt',
#  'inputs/1712.txt',
#  'inputs/1713.txt',
#  'inputs/1714.txt',
#  'inputs/1715.txt',
#  'inputs/1716.txt',
#  'inputs/1717.txt',
#  'inputs/1718.txt',
#  'inputs/1719.txt',
#  'inputs/172.txt',
#  'inputs/1720.txt',
#  'inputs/1721.txt',
#  'inputs/1722.txt',
#  'inputs/1723.txt',
#  'inputs/1724.txt',
#  'inputs/1725.txt',
#  'inputs/1726.txt',
#  'inputs/1727.txt',
#  'inputs/1728.txt',
#  'inputs/1729.txt',
#  'inputs/173.txt',
#  'inputs/1730.txt',
#  'inputs/1731.txt',
#  'inputs/1732.txt',
#  'inputs/1733.txt',
#  'inputs/1734.txt',
#  'inputs/1735.txt',
#  'inputs/1736.txt',
#  'inputs/1737.txt',
#  'inputs/1738.txt',
#  'inputs/1739.txt',
#  'inputs/174.txt',
#  'inputs/1740.txt',
#  'inputs/1741.txt',
#  'inputs/1742.txt',
#  'inputs/1743.txt',
#  'inputs/1744.txt',
#  'inputs/1745.txt',
#  'inputs/1746.txt',
#  'inputs/1747.txt',
#  'inputs/1748.txt',
#  'inputs/1749.txt',
#  'inputs/175.txt',
#  'inputs/1750.txt',
#  'inputs/1751.txt',
#  'inputs/1752.txt',
#  'inputs/1753.txt',
#  'inputs/1754.txt',
#  'inputs/1755.txt',
#  'inputs/1756.txt',
#  'inputs/1757.txt',
#  'inputs/1758.txt',
#  'inputs/1759.txt',
#  'inputs/176.txt',
#  'inputs/1760.txt',
#  'inputs/1761.txt',
#  'inputs/1762.txt',
#  'inputs/1763.txt',
#  'inputs/1764.txt',
#  'inputs/1765.txt',
#  'inputs/1766.txt',
#  'inputs/1767.txt',
#  'inputs/1768.txt',
#  'inputs/1769.txt',
#  'inputs/177.txt',
#  'inputs/1770.txt',
#  'inputs/1771.txt',
#  'inputs/1772.txt',
#  'inputs/1773.txt',
#  'inputs/1774.txt',
#  'inputs/1775.txt',
#  'inputs/1776.txt',
#  'inputs/1777.txt',
#  'inputs/1778.txt',
#  'inputs/1779.txt',
#  'inputs/178.txt',
#  'inputs/1780.txt',
#  'inputs/1781.txt',
#  'inputs/1782.txt',
#  'inputs/1783.txt',
#  'inputs/1784.txt',
#  'inputs/1785.txt',
#  'inputs/1786.txt',
#  'inputs/1787.txt',
#  'inputs/1788.txt',
#  'inputs/1789.txt',
#  'inputs/179.txt',
#  'inputs/1790.txt',
#  'inputs/1791.txt',
#  'inputs/1792.txt',
#  'inputs/1793.txt',
#  'inputs/1794.txt',
#  'inputs/1795.txt',
#  'inputs/1796.txt',
#  'inputs/1797.txt',
#  'inputs/1798.txt',
#  'inputs/1799.txt',
#  'inputs/18.txt',
#  'inputs/180.txt',
#  'inputs/1800.txt',
#  'inputs/1801.txt',
#  'inputs/1802.txt',
#  'inputs/1803.txt',
#  'inputs/1804.txt',
#  'inputs/1805.txt',
#  'inputs/1806.txt',
#  'inputs/1807.txt',
#  'inputs/1808.txt',
#  'inputs/1809.txt',
#  'inputs/181.txt',
#  'inputs/1810.txt',
#  'inputs/1811.txt',
#  'inputs/1812.txt',
#  'inputs/1813.txt',
#  'inputs/1814.txt',
#  'inputs/1815.txt',
#  'inputs/1816.txt',
#  'inputs/1817.txt',
#  'inputs/1818.txt',
#  'inputs/1819.txt',
#  'inputs/182.txt',
#  'inputs/1820.txt',
#  'inputs/1821.txt',
#  'inputs/1822.txt',
#  'inputs/1823.txt',
#  'inputs/1824.txt',
#  'inputs/1825.txt',
#  'inputs/1826.txt',
#  'inputs/1827.txt',
#  'inputs/1828.txt',
#  'inputs/1829.txt',
#  'inputs/183.txt',
#  'inputs/1830.txt',
#  'inputs/1831.txt',
#  'inputs/1832.txt',
#  'inputs/1833.txt',
#  'inputs/1834.txt',
#  'inputs/1835.txt',
#  'inputs/1836.txt',
#  'inputs/1837.txt',
#  'inputs/1838.txt',
#  'inputs/1839.txt',
#  'inputs/184.txt',
#  'inputs/1840.txt',
#  'inputs/1841.txt',
#  'inputs/1842.txt',
#  'inputs/1843.txt',
#  'inputs/1844.txt',
#  'inputs/1845.txt',
#  'inputs/1846.txt',
#  'inputs/1847.txt',
#  'inputs/1848.txt',
#  'inputs/1849.txt',
#  'inputs/185.txt',
#  'inputs/1850.txt',
#  'inputs/1851.txt',
#  'inputs/1852.txt',
#  'inputs/1853.txt',
#  'inputs/1854.txt',
#  'inputs/1855.txt',
#  'inputs/1856.txt',
#  'inputs/1857.txt',
#  'inputs/1858.txt',
#  'inputs/1859.txt',
#  'inputs/186.txt',
#  'inputs/1860.txt',
#  'inputs/1861.txt',
#  'inputs/1862.txt',
#  'inputs/1863.txt',
#  'inputs/1864.txt',
#  'inputs/1865.txt',
#  'inputs/1866.txt',
#  'inputs/1867.txt',
#  'inputs/1868.txt',
#  'inputs/1869.txt',
#  'inputs/187.txt',
#  'inputs/1870.txt',
#  'inputs/1871.txt',
#  'inputs/1872.txt',
#  'inputs/1873.txt',
#  'inputs/1874.txt',
#  'inputs/1875.txt',
#  'inputs/1876.txt',
#  'inputs/1877.txt',
#  'inputs/1878.txt',
#  'inputs/1879.txt',
#  'inputs/188.txt',
#  'inputs/1880.txt',
#  'inputs/1881.txt',
#  'inputs/1882.txt',
#  'inputs/1883.txt',
#  'inputs/1884.txt',
#  'inputs/1885.txt',
#  'inputs/1886.txt',
#  'inputs/1887.txt',
#  'inputs/1888.txt',
#  'inputs/1889.txt',
#  'inputs/189.txt',
#  'inputs/1890.txt',
#  'inputs/1891.txt',
#  'inputs/1892.txt',
#  'inputs/1893.txt',
#  'inputs/1894.txt',
#  'inputs/1895.txt',
#  'inputs/1896.txt',
#  'inputs/1897.txt',
#  'inputs/1898.txt',
#  'inputs/1899.txt',
#  ...]

# %% [markdown]
# Test file size. We'll only keep the ones above a certain size, say 300 bytes.

# %%
filenames = [x for x in filenames if os.path.getsize(x) > 300]

# %% [markdown]
# ### LDA Topic Modeling
# Now let's try running the same corpus through LDA. Here we'll use the gensim module, which provides a [standard API](https://radimrehurek.com/gensim/apiref.html) for working with corpora. The gensim module has its own implementation of LDA and also includes a nice wrapper for MALLET, which means if we must use MALLET we don't have to mess with Java and the command line at all if we don't want to, and we don't have to keep track of all the temporary text files it generates.

# %%
from gensim import corpora, models, utils
import nltk

# %% [markdown]
# We'll use gensim to create a quick corpus from our text files. We could customize the tokenization however we want. We'll need a stoplist, and can use whatever we want. Here we'll use one from the nltk module.

# %%
stoplist = set(nltk.corpus.stopwords.words("english"))

class MyCorpus(corpora.TextCorpus): 
    def get_texts(self): 
        for filename in filenames:
            yield (x for x in 
                utils.tokenize(open(filename).read(), lowercase=True, deacc=True, errors="ignore")
            if x not in stoplist)

corpus = MyCorpus(filenames)

# %% [markdown]
# We've already removed stopwords; now let's get rid of any words that appear in just one document.

# %%
corpus.dictionary.filter_extremes(no_below=1)

# %%
print(corpus.dictionary)
# Out:
# Dictionary(90343 unique tokens: ['kaigaya', 'piwik', 'wallenberger', 'demasiado', 'ma³n']...)

# %% [markdown]
# The gensim module merely points to MALLET, which you'll still need to have installed, and you'll need to tell gensim where to find it.

# %%
mallet_path = '/Users/stakats/Development/mallet-2.0.7/bin/mallet'

# %% [markdown]
# Now we'll use the gensim wrapper to run MALLET on our newly created corpus. We can set whatever MALLET parameters we want right from here.

# %%
model = models.wrappers.LdaMallet(mallet_path, corpus, num_topics=40, optimize_interval=10, id2word=corpus.dictionary)

# %% [markdown]
# Now that we've run MALLET, we can take a quick look at the topic keys generated.

# %%
doctopics = models.wrappers.LdaMallet.fdoctopics(model)
topickeys = models.wrappers.LdaMallet.ftopickeys(model)

# %% [markdown]
# Now we'll dump the doctopics into a dataframe, and then add the filenames as a column because gensim doesn't keep track of this metadata.

# %%
import pandas as pd
import numpy as np
import itertools
import operator
import os

# %% [markdown]
# We have to jump through a lot of hoops to rearrange the MALLET output into a form that's usable.

# %%
def grouper(n, iterable, fillvalue=None):
    "Collect data into fixed-length chunks or blocks"
    args = [iter(iterable)] * n
    return itertools.zip_longest(*args, fillvalue=fillvalue)

# %%
doctopic_triples = []
mallet_docnames = []

# %%
with open(doctopics) as f:
    f.readline()  # read one line in order to skip the header
    for line in f:
        docnum, docname, *values = line.rstrip().split('\t')
        mallet_docnames.append(docname)
        for topic, share in grouper(2, values):
            triple = (docname, int(topic), float(share))
            doctopic_triples.append(triple)

# %%
doctopic_triples = sorted(doctopic_triples, key=operator.itemgetter(0,1))

# %%
num_docs = len(mallet_docnames)

# %%
num_topics = len(doctopic_triples) // len(mallet_docnames)

# %%
doctopic = np.zeros((num_docs, num_topics))

# %%
for triple in doctopic_triples:
    docname, topic, share = triple
    row_num = mallet_docnames.index(docname)
    doctopic[row_num, topic] = share

# %%
df = pd.DataFrame(doctopic_triples)

# %%
table = pd.pivot_table(df, values=2, index=[0], columns=[1], aggfunc=np.sum)

# %%
table.index.name = 'id'

# %%
table.reset_index(inplace=True)

# %%
table = table.applymap(float)

# %%
table = table.sort(['id'], ascending=[1])

# %%
indexed_df = table.set_index(['id'])

# %%
indexed_df
# Out:
# 1           0         1         2         3         4         5         6   \
# id
# 0     0.000021  0.011385  0.000077  0.001170  0.184208  0.123002  0.000166
# 1     0.000086  0.490842  0.000320  0.004853  0.003526  0.003167  0.000688
# 2     0.000051  0.002928  0.000188  0.164677  0.002078  0.001866  0.000405
# 3     0.000116  0.034956  0.000428  0.006501  0.004724  0.004242  0.000921
# 4     0.000126  0.007275  0.000468  0.038028  0.005162  0.004636  0.001007
# 5     0.000062  0.003546  0.000228  0.003463  0.002516  0.002260  0.000491
# 6     0.000012  0.054870  0.000046  0.235392  0.235203  0.000451  0.000098
# 7     0.000032  0.001819  0.000117  0.001776  0.009022  0.001159  0.000252
# 8     0.000110  0.327693  0.000405  0.006153  0.004470  0.030798  0.000872
# 9     0.000116  0.006658  0.000428  0.006501  0.004724  0.004242  0.000921
# 10    0.000090  0.181643  0.000334  0.005067  0.003682  0.003306  0.000718
# 11    0.000078  0.004495  0.000289  0.004389  0.270684  0.002864  0.077049
# 12    0.000012  0.176635  0.000043  0.051739  0.000474  0.000425  0.000092
# 13    0.000126  0.007275  0.031392  0.007104  0.005162  0.004636  0.093778
# 14    0.020813  0.001630  0.000105  0.001592  0.001156  0.001039  0.000226
# 15    0.000107  0.136557  0.000395  0.005992  0.004354  0.003910  0.000849
# 16    0.000113  0.006474  0.000416  0.006322  0.004594  0.004125  0.000896
# 17    0.000130  0.071329  0.000483  0.007331  0.069148  0.036694  0.001039
# 18    0.000092  0.005306  0.000341  0.072844  0.003765  0.003381  0.000734
# 19    0.000024  0.001381  0.000089  0.018961  0.000980  0.000880  0.000191
# 20    0.000050  0.027481  0.000186  0.002824  0.124997  0.001843  0.000400
# 21    0.000097  0.005557  0.047597  0.005426  0.003943  0.003541  0.000769
# 22    0.000119  0.356323  0.000441  0.006690  0.004861  0.004366  0.000948
# 23    0.000011  0.179335  0.000041  0.000622  0.000452  0.000406  0.000088
# 24    0.000031  0.129260  0.000113  0.016722  0.001252  0.016124  0.000244
# 25    0.000041  0.002368  0.000152  0.022446  0.021814  0.001509  0.000328
# 26    0.000119  0.006852  0.000441  0.035813  0.004861  0.004366  0.000948
# 27    0.000034  0.027110  0.000127  0.211415  0.001399  0.177228  0.000273
# 28    0.000110  0.006301  0.000405  0.006153  0.004470  0.004015  0.000872
